# %%
#Вводим с консоли число от 0 до 1000. Выводим меньшуюи большую цифру числа. (Пример: 15 => 1 -меньшая, 5 - большая)
m = input()
# Out:
# 15

# %%
s = list(m)
print(s)
# Out:
# ['1', '5']

# %%
min(s)
# Out:
# '1'

# %%
max(s)
# Out:
# '5'

# %%
#Нужно хранить соответствие месяцу порядкового номера от 0 до 11. С консоли вводим либо номер месяца от 0 до 11 => 
#получаем название месяца, вводим название месяца => получаем порядковый номер месяца
year_ = {}
year_['Jan'] = 0
year_['Feb'] = 1
year_['Mar'] = 2
year_['Apr'] = 3
year_['May'] = 4
year_['Jun'] = 5
year_['Jul'] = 6
year_['Aug'] = 7
year_['Sep'] = 8
year_['Oct'] = 9
year_['Nov'] = 10
year_['Dec'] = 11
print(year_)
# Out:
# {'Jan': 0, 'Feb': 1, 'Mar': 2, 'Apr': 3, 'May': 4, 'Jun': 5, 'Jul': 6, 'Aug': 7, 'Sep': 8, 'Oct': 9, 'Nov': 10, 'Dec': 11}

# %%
print('Введите название месяца ' + '\n') 
vl = year_.get(input(),'None')
print(vl)
# Out:
# Введите название месяца
#
# Jab
# None

# %%
print('Введите номер месяца '+'\n')
b = list(year_.keys())
i = input()
print(b[int(i)])
# Out:
# Введите номер месяца
#
# 20
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-64-78fe2e8bbe65> in <module>()
#       2 b = list(year_.keys())
#       3 i = input()
# ----> 4 print(b[int(i)])
#
# IndexError: list index out of range

# %%
# Возьмите любой текст из книги, в котором есть побольше знаков. Привести все слова к нижнему регистру. 
#Составьте свое соответствие знака препинания и слова (например “.” => “[dot]” и тд). 
#Замените все знаки в тесте на их представление. Получить частоту вхождения в текст каждого слова
#(включая представления знаков). Составить представление текста вида слово => список номеров слова в тексте 
#(Пример: “мама мыла мама” => “мама”: [0,2])

# %%
str = """
У вашего идеала был неумолимый враг, уничтожить которого был призван ваш моральный кодекс. Я уничтожил этого врага. Я убрал его с вашего пути и из пределов вашей досягаемости. Я удалил источник всех тех зол, которое вы одно за другим приносили в жертву. Я закончил вашу битву. Я остановил ваш двигатель. Я лишил ваш мир человеческого разума.
Люди не живут разумом, говорите вы? Я убрал тех, кто им живет. Разум бессилен, говорите вы? Я убрал тех, чей разум силен. Есть ценности более высокие, чем разум, говорите вы? Я убрал тех, для кого разум наивысшая ценность.
В то время как вы тащили на заклание людей, веривших в справедливость, независимость, разум, богатство, собственное достоинство, я опередил вас, я пришел к ним первым. Я объяснил им суть той игры, в которую вы играете, и вашего морального кодекса, понять которые они, будучи слишком невинными и благородными, не могли. Я показал им, как можно жить, согласуясь с иной моралью — моей. И они предпочли следовать моей морали.
"""

# %%
str_1 = str.capitalize().replace('.',' :dot ').replace(',',' :comma ').replace('?',' :question ').replace('-',' :dash ').replace('\n','').replace('  ',' ')
print(str_1)
# Out:
# у вашего идеала был неумолимый враг :comma уничтожить которого был призван ваш моральный кодекс :dot я уничтожил этого врага :dot я убрал его с вашего пути и из пределов вашей досягаемости :dot я удалил источник всех тех зол :comma которое вы одно за другим приносили в жертву :dot я закончил вашу битву :dot я остановил ваш двигатель :dot я лишил ваш мир человеческого разума :dot люди не живут разумом :comma говорите вы :question я убрал тех :comma кто им живет :dot разум бессилен :comma говорите вы :question я убрал тех :comma чей разум силен :dot есть ценности более высокие :comma чем разум :comma говорите вы :question я убрал тех :comma для кого разум наивысшая ценность :dot в то время как вы тащили на заклание людей :comma веривших в справедливость :comma независимость :comma разум :comma богатство :comma собственное достоинство :comma я опередил вас :comma я пришел к ним первым :dot я объяснил им суть той игры :comma в которую вы играете :comma и вашего морального кодекса :comma понять которые они :comma будучи слишком невинными и благородными :comma не могли :dot я показал им :comma как можно жить :comma согласуясь с иной моралью — моей :dot и они предпочли следовать моей морали :dot

# %%
str_2 = str_1.split(' ')
print(str_2)
# Out:
# ['у', 'вашего', 'идеала', 'был', 'неумолимый', 'враг', ':comma', 'уничтожить', 'которого', 'был', 'призван', 'ваш', 'моральный', 'кодекс', ':dot', 'я', 'уничтожил', 'этого', 'врага', ':dot', 'я', 'убрал', 'его', 'с', 'вашего', 'пути', 'и', 'из', 'пределов', 'вашей', 'досягаемости', ':dot', 'я', 'удалил', 'источник', 'всех', 'тех', 'зол', ':comma', 'которое', 'вы', 'одно', 'за', 'другим', 'приносили', 'в', 'жертву', ':dot', 'я', 'закончил', 'вашу', 'битву', ':dot', 'я', 'остановил', 'ваш', 'двигатель', ':dot', 'я', 'лишил', 'ваш', 'мир', 'человеческого', 'разума', ':dot', 'люди', 'не', 'живут', 'разумом', ':comma', 'говорите', 'вы', ':question', 'я', 'убрал', 'тех', ':comma', 'кто', 'им', 'живет', ':dot', 'разум', 'бессилен', ':comma', 'говорите', 'вы', ':question', 'я', 'убрал', 'тех', ':comma', 'чей', 'разум', 'силен', ':dot', 'есть', 'ценности', 'более', 'высокие', ':comma', 'чем', 'разум', ':comma', 'говорите', 'вы', ':question', 'я', 'убрал', 'тех', ':comma', 'для', 'кого', 'разум', 'наивысшая', 'ценность', ':dot', 'в', 'то', 'время', 'как', 'вы', 'тащили', 'на', 'заклание', 'людей', ':comma', 'веривших', 'в', 'справедливость', ':comma', 'независимость', ':comma', 'разум', ':comma', 'богатство', ':comma', 'собственное', 'достоинство', ':comma', 'я', 'опередил', 'вас', ':comma', 'я', 'пришел', 'к', 'ним', 'первым', ':dot', 'я', 'объяснил', 'им', 'суть', 'той', 'игры', ':comma', 'в', 'которую', 'вы', 'играете', ':comma', 'и', 'вашего', 'морального', 'кодекса', ':comma', 'понять', 'которые', 'они', ':comma', 'будучи', 'слишком', 'невинными', 'и', 'благородными', ':comma', 'не', 'могли', ':dot', 'я', 'показал', 'им', ':comma', 'как', 'можно', 'жить', ':comma', 'согласуясь', 'с', 'иной', 'моралью', '—', 'моей', ':dot', 'и', 'они', 'предпочли', 'следовать', 'моей', 'морали', ':dot', '']

# %%
from collections import Counter

# %%
wqty = Counter(str_2)
print(wqty)
# Out:
# Counter({':comma': 23, ':dot': 14, 'я': 13, 'вы': 6, 'разум': 5, 'убрал': 4, 'и': 4, 'тех': 4, 'в': 4, 'вашего': 3, 'ваш': 3, 'говорите': 3, ':question': 3, 'им': 3, 'был': 2, 'с': 2, 'не': 2, 'как': 2, 'они': 2, 'моей': 2, 'у': 1, 'идеала': 1, 'неумолимый': 1, 'враг': 1, 'уничтожить': 1, 'которого': 1, 'призван': 1, 'моральный': 1, 'кодекс': 1, 'уничтожил': 1, 'этого': 1, 'врага': 1, 'его': 1, 'пути': 1, 'из': 1, 'пределов': 1, 'вашей': 1, 'досягаемости': 1, 'удалил': 1, 'источник': 1, 'всех': 1, 'зол': 1, 'которое': 1, 'одно': 1, 'за': 1, 'другим': 1, 'приносили': 1, 'жертву': 1, 'закончил': 1, 'вашу': 1, 'битву': 1, 'остановил': 1, 'двигатель': 1, 'лишил': 1, 'мир': 1, 'человеческого': 1, 'разума': 1, 'люди': 1, 'живут': 1, 'разумом': 1, 'кто': 1, 'живет': 1, 'бессилен': 1, 'чей': 1, 'силен': 1, 'есть': 1, 'ценности': 1, 'более': 1, 'высокие': 1, 'чем': 1, 'для': 1, 'кого': 1, 'наивысшая': 1, 'ценность': 1, 'то': 1, 'время': 1, 'тащили': 1, 'на': 1, 'заклание': 1, 'людей': 1, 'веривших': 1, 'справедливость': 1, 'независимость': 1, 'богатство': 1, 'собственное': 1, 'достоинство': 1, 'опередил': 1, 'вас': 1, 'пришел': 1, 'к': 1, 'ним': 1, 'первым': 1, 'объяснил': 1, 'суть': 1, 'той': 1, 'игры': 1, 'которую': 1, 'играете': 1, 'морального': 1, 'кодекса': 1, 'понять': 1, 'которые': 1, 'будучи': 1, 'слишком': 1, 'невинными': 1, 'благородными': 1, 'могли': 1, 'показал': 1, 'можно': 1, 'жить': 1, 'согласуясь': 1, 'иной': 1, 'моралью': 1, '—': 1, 'предпочли': 1, 'следовать': 1, 'морали': 1, '': 1})

# %%
uniq_w = set(str_2)
uniq_w
# Out:
# {'',
#  ':comma',
#  ':dot',
#  ':question',
#  'бессилен',
#  'битву',
#  'благородными',
#  'богатство',
#  'более',
#  'будучи',
#  'был',
#  'в',
#  'вас',
#  'ваш',
#  'вашего',
#  'вашей',
#  'вашу',
#  'веривших',
#  'враг',
#  'врага',
#  'время',
#  'всех',
#  'вы',
#  'высокие',
#  'говорите',
#  'двигатель',
#  'для',
#  'достоинство',
#  'досягаемости',
#  'другим',
#  'его',
#  'есть',
#  'жертву',
#  'живет',
#  'живут',
#  'жить',
#  'за',
#  'заклание',
#  'закончил',
#  'зол',
#  'и',
#  'играете',
#  'игры',
#  'идеала',
#  'из',
#  'им',
#  'иной',
#  'источник',
#  'к',
#  'как',
#  'кого',
#  'кодекс',
#  'кодекса',
#  'которого',
#  'которое',
#  'которую',
#  'которые',
#  'кто',
#  'лишил',
#  'людей',
#  'люди',
#  'мир',
#  'могли',
#  'моей',
#  'можно',
#  'морали',
#  'морального',
#  'моральный',
#  'моралью',
#  'на',
#  'наивысшая',
#  'не',
#  'невинными',
#  'независимость',
#  'неумолимый',
#  'ним',
#  'объяснил',
#  'одно',
#  'они',
#  'опередил',
#  'остановил',
#  'первым',
#  'показал',
#  'понять',
#  'пределов',
#  'предпочли',
#  'призван',
#  'приносили',
#  'пришел',
#  'пути',
#  'разум',
#  'разума',
#  'разумом',
#  'с',
#  'силен',
#  'следовать',
#  'слишком',
#  'собственное',
#  'согласуясь',
#  'справедливость',
#  'суть',
#  'тащили',
#  'тех',
#  'то',
#  'той',
#  'у',
#  'убрал',
#  'удалил',
#  'уничтожил',
#  'уничтожить',
#  'ценности',
#  'ценность',
#  'чей',
#  'человеческого',
#  'чем',
#  'этого',
#  'я',
#  '—'}

# %%
#for i in str_2:
#    for w in uniq_w:
#        if w in i:
#            print(w)
#            print(str_2.index(i))

# %%
for i in uniq_w:
    s = dict.fromkeys(i, str_1.index(i))
s
# Out:
# {'и': 1140, 'й': 1140, 'н': 1140, 'о': 1140}
